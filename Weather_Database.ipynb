# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | roanoke rapids
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | vila velha
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | ust-tsilma
# Processing Record 18 of Set 1 | steamboat springs
# Processing Record 19 of Set 1 | areosa
# Processing Record 20 of Set 1 | pacific grove
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | tiarei
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | warrington
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | opochka
# Processing Record 27 of Set 1 | namatanai
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 30 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | ostrovnoy
# Processing Record 33 of Set 1 | ucluelet
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | pisco
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | perdoes
# Processing Record 43 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | talnakh
# Processing Record 47 of Set 1 | warmbad
# Processing Record 48 of Set 1 | duma
# Processing Record 49 of Set 1 | san policarpo
# Processing Record 50 of Set 1 | namibe
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | luanda
# Processing Record 3 of Set 2 | san ramon
# Processing Record 4 of Set 2 | tecoanapa
# Processing Record 5 of Set 2 | san pedro
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | adre
# Processing Record 8 of Set 2 | mao
# Processing Record 9 of Set 2 | salekhard
# Processing Record 10 of Set 2 | sao joao da barra
# Processing Record 11 of Set 2 | kulim
# Processing Record 12 of Set 2 | bria
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | tezu
# Processing Record 15 of Set 2 | vincennes
# Processing Record 16 of Set 2 | saint-joseph
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | korla
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | camacha
# Processing Record 22 of Set 2 | sabha
# Processing Record 23 of Set 2 | sterling
# Processing Record 24 of Set 2 | vallentuna
# Processing Record 25 of Set 2 | akyab
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | hambantota
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | bucerias
# Processing Record 30 of Set 2 | egvekinot
# Processing Record 31 of Set 2 | honiara
# Processing Record 32 of Set 2 | kapaa
# Processing Record 33 of Set 2 | ryotsu
# Processing Record 34 of Set 2 | quatre cocos
# Processing Record 35 of Set 2 | ahlat
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | lasa
# Processing Record 38 of Set 2 | praya
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | viedma
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | florianopolis
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | mecca
# Processing Record 1 of Set 3 | lagoa
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | ilulissat
# Processing Record 4 of Set 3 | cidreira
# Processing Record 5 of Set 3 | allacapan
# Processing Record 6 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 3 | pangoa
# Processing Record 8 of Set 3 | laguna
# Processing Record 9 of Set 3 | snyder
# Processing Record 10 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | buraydah
# Processing Record 13 of Set 3 | richmond
# Processing Record 14 of Set 3 | manokwari
# Processing Record 15 of Set 3 | buchanan
# Processing Record 16 of Set 3 | alice springs
# Processing Record 17 of Set 3 | sassandra
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | flinders
# Processing Record 20 of Set 3 | hami
# Processing Record 21 of Set 3 | husavik
# Processing Record 22 of Set 3 | vostok
# Processing Record 23 of Set 3 | siverskiy
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | samarai
# Processing Record 26 of Set 3 | richards bay
# Processing Record 27 of Set 3 | valreas
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | el tigre
# Processing Record 32 of Set 3 | qaanaaq
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | gilleleje
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | mananjary
# Processing Record 37 of Set 3 | puerto escondido
# Processing Record 38 of Set 3 | coahuayana
# Processing Record 39 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 3 | kandiaro
# Processing Record 41 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | mtwara
# Processing Record 44 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 3 | port alfred
# Processing Record 46 of Set 3 | jacareacanga
# Processing Record 47 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | haapu
# City not found. Skipping...
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | sorland
# Processing Record 6 of Set 4 | sangar
# Processing Record 7 of Set 4 | bridlington
# Processing Record 8 of Set 4 | san ramon de la nueva oran
# Processing Record 9 of Set 4 | miyako
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | porosozero
# Processing Record 12 of Set 4 | zorgo
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | raudeberg
# Processing Record 15 of Set 4 | marzuq
# Processing Record 16 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 4 | ahipara
# Processing Record 18 of Set 4 | palotina
# Processing Record 19 of Set 4 | aloleng
# Processing Record 20 of Set 4 | nizwa
# Processing Record 21 of Set 4 | suffolk
# Processing Record 22 of Set 4 | aklavik
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | sinnamary
# Processing Record 26 of Set 4 | san francisco
# Processing Record 27 of Set 4 | ishigaki
# Processing Record 28 of Set 4 | mbandaka
# Processing Record 29 of Set 4 | goderich
# Processing Record 30 of Set 4 | mazamitla
# Processing Record 31 of Set 4 | hasaki
# Processing Record 32 of Set 4 | barra patuca
# Processing Record 33 of Set 4 | fuyu
# Processing Record 34 of Set 4 | antofagasta
# Processing Record 35 of Set 4 | sigulda
# Processing Record 36 of Set 4 | mubi
# Processing Record 37 of Set 4 | alta floresta
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 4 | sorong
# Processing Record 41 of Set 4 | lavrentiya
# Processing Record 42 of Set 4 | port hardy
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | juba
# Processing Record 45 of Set 4 | la ronge
# Processing Record 46 of Set 4 | honningsvag
# Processing Record 47 of Set 4 | riyadh
# Processing Record 48 of Set 4 | newport
# Processing Record 49 of Set 4 | longyearbyen
# Processing Record 50 of Set 4 | alexandria
# Processing Record 1 of Set 5 | smolenka
# Processing Record 2 of Set 5 | kaa-khem
# Processing Record 3 of Set 5 | evensk
# Processing Record 4 of Set 5 | qesarya
# Processing Record 5 of Set 5 | broome
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | bardiyah
# Processing Record 8 of Set 5 | new norfolk
# Processing Record 9 of Set 5 | amuntai
# Processing Record 10 of Set 5 | jamestown
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | mizdah
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | trinidad
# Processing Record 16 of Set 5 | shushenskoye
# Processing Record 17 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | ballina
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | padang
# Processing Record 22 of Set 5 | huilong
# Processing Record 23 of Set 5 | dudinka
# Processing Record 24 of Set 5 | lesnoy
# Processing Record 25 of Set 5 | konstantinovka
# Processing Record 26 of Set 5 | areia branca
# Processing Record 27 of Set 5 | kijang
# Processing Record 28 of Set 5 | hillsborough
# Processing Record 29 of Set 5 | shaki
# Processing Record 30 of Set 5 | lata
# Processing Record 31 of Set 5 | sungaipenuh
# Processing Record 32 of Set 5 | nemuro
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 5 | jenison
# Processing Record 36 of Set 5 | sao jose da coroa grande
# Processing Record 37 of Set 5 | norman wells
# Processing Record 38 of Set 5 | puerto madryn
# Processing Record 39 of Set 5 | agva
# City not found. Skipping...
# Processing Record 40 of Set 5 | verkh-usugli
# Processing Record 41 of Set 5 | bathsheba
# Processing Record 42 of Set 5 | ternate
# Processing Record 43 of Set 5 | kudahuvadhoo
# Processing Record 44 of Set 5 | bandarbeyla
# Processing Record 45 of Set 5 | caravelas
# Processing Record 46 of Set 5 | sola
# Processing Record 47 of Set 5 | saint-augustin
# Processing Record 48 of Set 5 | ulladulla
# Processing Record 49 of Set 5 | mahajanga
# Processing Record 50 of Set 5 | tupi paulista
# Processing Record 1 of Set 6 | karratha
# Processing Record 2 of Set 6 | nhulunbuy
# Processing Record 3 of Set 6 | mar del plata
# Processing Record 4 of Set 6 | nuuk
# Processing Record 5 of Set 6 | tulagi
# Processing Record 6 of Set 6 | pyapon
# Processing Record 7 of Set 6 | cuenca
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | puerto ayacucho
# Processing Record 10 of Set 6 | avarua
# Processing Record 11 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 6 | roebourne
# Processing Record 13 of Set 6 | dingle
# Processing Record 14 of Set 6 | adrar
# Processing Record 15 of Set 6 | west des moines
# Processing Record 16 of Set 6 | lagos
# Processing Record 17 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 6 | belaya gora
# Processing Record 19 of Set 6 | kaitangata
# Processing Record 20 of Set 6 | thinadhoo
# Processing Record 21 of Set 6 | kamenka
# Processing Record 22 of Set 6 | rantauprapat
# Processing Record 23 of Set 6 | bischofshofen
# Processing Record 24 of Set 6 | saint george
# Processing Record 25 of Set 6 | codrington
# Processing Record 26 of Set 6 | asilah
# Processing Record 27 of Set 6 | torbay
# Processing Record 28 of Set 6 | waitati
# Processing Record 29 of Set 6 | olinda
# Processing Record 30 of Set 6 | bandar-e anzali
# Processing Record 31 of Set 6 | las choapas
# Processing Record 32 of Set 6 | airai
# Processing Record 33 of Set 6 | maceio
# Processing Record 34 of Set 6 | guarenas
# Processing Record 35 of Set 6 | fairlie
# Processing Record 36 of Set 6 | kloulklubed
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | alugan
# Processing Record 39 of Set 6 | asau
# Processing Record 40 of Set 6 | shuangyang
# Processing Record 41 of Set 6 | hinton
# Processing Record 42 of Set 6 | rehoboth
# Processing Record 43 of Set 6 | wasilla
# Processing Record 44 of Set 6 | fairbanks
# Processing Record 45 of Set 6 | bagan
# Processing Record 46 of Set 6 | kindu
# Processing Record 47 of Set 6 | savannah bight
# Processing Record 48 of Set 6 | komatipoort
# Processing Record 49 of Set 6 | nome
# Processing Record 50 of Set 6 | ciudad bolivar
# Processing Record 1 of Set 7 | francistown
# Processing Record 2 of Set 7 | dwarka
# Processing Record 3 of Set 7 | lorengau
# Processing Record 4 of Set 7 | kingaroy
# Processing Record 5 of Set 7 | kichera
# Processing Record 6 of Set 7 | birkeland
# Processing Record 7 of Set 7 | mindelo
# Processing Record 8 of Set 7 | chopovychi
# Processing Record 9 of Set 7 | tighina
# Processing Record 10 of Set 7 | itarema
# Processing Record 11 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 7 | fallon
# Processing Record 13 of Set 7 | pervomayskoye
# Processing Record 14 of Set 7 | xihe
# Processing Record 15 of Set 7 | broken hill
# Processing Record 16 of Set 7 | los llanos de aridane
# Processing Record 17 of Set 7 | qixingtai
# Processing Record 18 of Set 7 | lano
# Processing Record 19 of Set 7 | paratinga
# Processing Record 20 of Set 7 | apache junction
# Processing Record 21 of Set 7 | dabola
# Processing Record 22 of Set 7 | senno
# Processing Record 23 of Set 7 | kurilsk
# Processing Record 24 of Set 7 | frunze
# Processing Record 25 of Set 7 | bubaque
# Processing Record 26 of Set 7 | miri
# Processing Record 27 of Set 7 | gat
# Processing Record 28 of Set 7 | visakhapatnam
# Processing Record 29 of Set 7 | bambanglipuro
# Processing Record 30 of Set 7 | inirida
# Processing Record 31 of Set 7 | tadine
# Processing Record 32 of Set 7 | cabedelo
# Processing Record 33 of Set 7 | salalah
# Processing Record 34 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 7 | kiunga
# Processing Record 36 of Set 7 | vanimo
# Processing Record 37 of Set 7 | turochak
# Processing Record 38 of Set 7 | pampa
# Processing Record 39 of Set 7 | grass valley
# Processing Record 40 of Set 7 | the valley
# Processing Record 41 of Set 7 | swan hill
# Processing Record 42 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | vao
# Processing Record 45 of Set 7 | abha
# Processing Record 46 of Set 7 | pizarro
# Processing Record 47 of Set 7 | baruun-urt
# Processing Record 48 of Set 7 | elat
# Processing Record 49 of Set 7 | lompoc
# Processing Record 50 of Set 7 | kaduqli
# Processing Record 1 of Set 8 | brae
# Processing Record 2 of Set 8 | almendralejo
# Processing Record 3 of Set 8 | savelugu
# Processing Record 4 of Set 8 | ixtapa
# Processing Record 5 of Set 8 | haines junction
# Processing Record 6 of Set 8 | jizan
# Processing Record 7 of Set 8 | nanortalik
# Processing Record 8 of Set 8 | pouebo
# Processing Record 9 of Set 8 | bontang
# Processing Record 10 of Set 8 | san miguel
# Processing Record 11 of Set 8 | vestmannaeyjar
# Processing Record 12 of Set 8 | meulaboh
# Processing Record 13 of Set 8 | castro
# Processing Record 14 of Set 8 | farmington
# Processing Record 15 of Set 8 | lora del rio
# Processing Record 16 of Set 8 | baglan
# Processing Record 17 of Set 8 | muscat
# Processing Record 18 of Set 8 | phalaborwa
# Processing Record 19 of Set 8 | coihaique
# Processing Record 20 of Set 8 | manadhoo
# Processing Record 21 of Set 8 | majene
# Processing Record 22 of Set 8 | cuamba
# Processing Record 23 of Set 8 | fukue
# Processing Record 24 of Set 8 | tonshayevo
# Processing Record 25 of Set 8 | labuhan
# Processing Record 26 of Set 8 | bafra
# Processing Record 27 of Set 8 | lima
# Processing Record 28 of Set 8 | whitehorse
# Processing Record 29 of Set 8 | jimma
# Processing Record 30 of Set 8 | ilhabela
# Processing Record 31 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | celestun
# Processing Record 33 of Set 8 | bodden town
# Processing Record 34 of Set 8 | necochea
# Processing Record 35 of Set 8 | arman
# Processing Record 36 of Set 8 | rorvik
# Processing Record 37 of Set 8 | ewa beach
# Processing Record 38 of Set 8 | carballo
# Processing Record 39 of Set 8 | mayo
# Processing Record 40 of Set 8 | kismayo
# Processing Record 41 of Set 8 | puerto cabezas
# Processing Record 42 of Set 8 | zhigansk
# Processing Record 43 of Set 8 | villanueva
# Processing Record 44 of Set 8 | la palma
# Processing Record 45 of Set 8 | barcelona
# Processing Record 46 of Set 8 | khorixas
# Processing Record 47 of Set 8 | peno
# Processing Record 48 of Set 8 | kirksville
# Processing Record 49 of Set 8 | havelian
# Processing Record 50 of Set 8 | seymchan
# Processing Record 1 of Set 9 | hofn
# Processing Record 2 of Set 9 | chernyshevskiy
# Processing Record 3 of Set 9 | alyangula
# Processing Record 4 of Set 9 | anyksciai
# Processing Record 5 of Set 9 | pangnirtung
# Processing Record 6 of Set 9 | yuzhno-kurilsk
# Processing Record 7 of Set 9 | saint anthony
# Processing Record 8 of Set 9 | kapoeta
# Processing Record 9 of Set 9 | emba
# Processing Record 10 of Set 9 | bogorodskoye
# Processing Record 11 of Set 9 | pearland
# Processing Record 12 of Set 9 | forbes
# Processing Record 13 of Set 9 | tigil
# Processing Record 14 of Set 9 | gboko
# Processing Record 15 of Set 9 | virginia beach
# Processing Record 16 of Set 9 | sawakin
# Processing Record 17 of Set 9 | anshun
# Processing Record 18 of Set 9 | makakilo city
# Processing Record 19 of Set 9 | hulan
# Processing Record 20 of Set 9 | stornoway
# Processing Record 21 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 9 | teseney
# Processing Record 23 of Set 9 | graaff-reinet
# Processing Record 24 of Set 9 | mangrol
# Processing Record 25 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 9 | omboue
# Processing Record 27 of Set 9 | silifke
# Processing Record 28 of Set 9 | minab
# Processing Record 29 of Set 9 | praia da vitoria
# Processing Record 30 of Set 9 | sur
# Processing Record 31 of Set 9 | beira
# Processing Record 32 of Set 9 | sobrance
# Processing Record 33 of Set 9 | trincomalee
# Processing Record 34 of Set 9 | chapais
# Processing Record 35 of Set 9 | hirara
# Processing Record 36 of Set 9 | mopipi
# Processing Record 37 of Set 9 | abu dhabi
# Processing Record 38 of Set 9 | elblag
# Processing Record 39 of Set 9 | puerto gaitan
# Processing Record 40 of Set 9 | sistranda
# Processing Record 41 of Set 9 | leicester
# Processing Record 42 of Set 9 | semporna
# Processing Record 43 of Set 9 | neuquen
# Processing Record 44 of Set 9 | katima mulilo
# Processing Record 45 of Set 9 | roma
# Processing Record 46 of Set 9 | souillac
# Processing Record 47 of Set 9 | paamiut
# Processing Record 48 of Set 9 | key largo
# Processing Record 49 of Set 9 | henties bay
# Processing Record 50 of Set 9 | kouango
# Processing Record 1 of Set 10 | takoradi
# Processing Record 2 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 10 | trat
# Processing Record 4 of Set 10 | lovozero
# Processing Record 5 of Set 10 | mackay
# Processing Record 6 of Set 10 | bluefields
# Processing Record 7 of Set 10 | elbrus
# Processing Record 8 of Set 10 | chakradharpur
# Processing Record 9 of Set 10 | mogadishu
# Processing Record 10 of Set 10 | tomatlan
# Processing Record 11 of Set 10 | kavieng
# Processing Record 12 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 10 | sao filipe
# Processing Record 14 of Set 10 | kailua
# Processing Record 15 of Set 10 | katherine
# Processing Record 16 of Set 10 | tsukumi
# Processing Record 17 of Set 10 | riberalta
# Processing Record 18 of Set 10 | calama
# Processing Record 19 of Set 10 | portland
# Processing Record 20 of Set 10 | oranjemund
# Processing Record 21 of Set 10 | katobu
# Processing Record 22 of Set 10 | slobozia
# Processing Record 23 of Set 10 | nelson bay
# Processing Record 24 of Set 10 | hafizabad
# Processing Record 25 of Set 10 | marawi
# Processing Record 26 of Set 10 | mocuba
# Processing Record 27 of Set 10 | rotenburg
# Processing Record 28 of Set 10 | contamana
# Processing Record 29 of Set 10 | kieta
# Processing Record 30 of Set 10 | kushima
# Processing Record 31 of Set 10 | mount isa
# Processing Record 32 of Set 10 | oktyabrskiy
# Processing Record 33 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 10 | peristera
# Processing Record 35 of Set 10 | bairiki
# Processing Record 36 of Set 10 | tateyama
# Processing Record 37 of Set 10 | ust-kut
# Processing Record 38 of Set 10 | alta
# Processing Record 39 of Set 10 | khani
# Processing Record 40 of Set 10 | sakaraha
# Processing Record 41 of Set 10 | nouadhibou
# Processing Record 42 of Set 10 | conde
# Processing Record 43 of Set 10 | christchurch
# Processing Record 44 of Set 10 | galle
# Processing Record 45 of Set 10 | naze
# Processing Record 46 of Set 10 | punta cardon
# Processing Record 47 of Set 10 | ewo
# Processing Record 48 of Set 10 | svetlyy
# Processing Record 49 of Set 10 | ancud
# Processing Record 50 of Set 10 | tautira
# Processing Record 1 of Set 11 | mankono
# Processing Record 2 of Set 11 | newburn
# Processing Record 3 of Set 11 | odweyne
# Processing Record 4 of Set 11 | tambacounda
# Processing Record 5 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 11 | alofi
# Processing Record 7 of Set 11 | isabela
# Processing Record 8 of Set 11 | gushikawa
# Processing Record 9 of Set 11 | bodo
# Processing Record 10 of Set 11 | khromtau
# Processing Record 11 of Set 11 | polunochnoye
# Processing Record 12 of Set 11 | rindal
# Processing Record 13 of Set 11 | aketi
# Processing Record 14 of Set 11 | kisangani
# Processing Record 15 of Set 11 | sabanalarga
# Processing Record 16 of Set 11 | ariquemes
# Processing Record 17 of Set 11 | otukpo
# Processing Record 18 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 11 | barber
# Processing Record 20 of Set 11 | urucara
# Processing Record 21 of Set 11 | smithers
# Processing Record 22 of Set 11 | krasnyy chikoy
# Processing Record 23 of Set 11 | high level
# Processing Record 24 of Set 11 | lere
# Processing Record 25 of Set 11 | tolosa
# Processing Record 26 of Set 11 | nokia
# Processing Record 27 of Set 11 | tiznit
# Processing Record 28 of Set 11 | faya
# Processing Record 29 of Set 11 | avera
# Processing Record 30 of Set 11 | nizhniy kuranakh
# Processing Record 31 of Set 11 | lahaina
# Processing Record 32 of Set 11 | segezha
# Processing Record 33 of Set 11 | angoche
# Processing Record 34 of Set 11 | shwebo
# Processing Record 35 of Set 11 | caldas novas
# Processing Record 36 of Set 11 | petersburg
# Processing Record 37 of Set 11 | goure
# Processing Record 38 of Set 11 | varnamo
# Processing Record 39 of Set 11 | hualmay
# Processing Record 40 of Set 11 | ponta delgada
# Processing Record 41 of Set 11 | oliveira do hospital
# Processing Record 42 of Set 11 | buala
# Processing Record 43 of Set 11 | lincoln
# Processing Record 44 of Set 11 | bourges
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | mehamn
# Processing Record 47 of Set 11 | pasni
# Processing Record 48 of Set 11 | oyon
# Processing Record 49 of Set 11 | half moon bay
# Processing Record 50 of Set 11 | acari
# Processing Record 1 of Set 12 | bilibino
# Processing Record 2 of Set 12 | yerbogachen
# Processing Record 3 of Set 12 | kapelle
# Processing Record 4 of Set 12 | whithorn
# Processing Record 5 of Set 12 | macheng
# Processing Record 6 of Set 12 | porto novo
# Processing Record 7 of Set 12 | thomaston
# Processing Record 8 of Set 12 | leshukonskoye
# Processing Record 9 of Set 12 | prince rupert
# Processing Record 10 of Set 12 | karpathos
# Processing Record 11 of Set 12 | linda
# Processing Record 12 of Set 12 | san cristobal
# Processing Record 13 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 12 | maloy
# Processing Record 15 of Set 12 | sahuaripa
# Processing Record 16 of Set 12 | mendi
# Processing Record 17 of Set 12 | hamilton
# Processing Record 18 of Set 12 | gurupa
# Processing Record 19 of Set 12 | starobaltachevo
# Processing Record 20 of Set 12 | makushino
# Processing Record 21 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 22 of Set 12 | tambura
# Processing Record 23 of Set 12 | vyazemskiy
# Processing Record 24 of Set 12 | zhangye
# Processing Record 25 of Set 12 | margate
# Processing Record 26 of Set 12 | segou
# Processing Record 27 of Set 12 | arlit
# Processing Record 28 of Set 12 | mercedes
# Processing Record 29 of Set 12 | nizhniy ingash
# Processing Record 30 of Set 12 | pilar do sul
# Processing Record 31 of Set 12 | zyryanka
# Processing Record 32 of Set 12 | nykoping
# Processing Record 33 of Set 12 | sishui
# Processing Record 34 of Set 12 | havelock
# Processing Record 35 of Set 12 | cururupu
# Processing Record 36 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 12 | chicama
# Processing Record 38 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 12 | kainantu
# Processing Record 40 of Set 12 | kalmunai
# Processing Record 41 of Set 12 | poco verde
# Processing Record 42 of Set 12 | biak
# Processing Record 43 of Set 12 | marsh harbour
# Processing Record 44 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 12 | fez
# Processing Record 46 of Set 12 | porterville
# Processing Record 47 of Set 12 | llanes
# Processing Record 48 of Set 12 | elk plain
# Processing Record 49 of Set 12 | ranong
# Processing Record 50 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 13 | rzhyshchiv
# Processing Record 2 of Set 13 | maxixe
# Processing Record 3 of Set 13 | albert town
# Processing Record 4 of Set 13 | methoni
# Processing Record 5 of Set 13 | ambrolauri
# Processing Record 6 of Set 13 | fortuna
# Processing Record 7 of Set 13 | perth
# Processing Record 8 of Set 13 | santa lucia
# Processing Record 9 of Set 13 | redcar
# Processing Record 10 of Set 13 | am timan
# Processing Record 11 of Set 13 | eyl
# Processing Record 12 of Set 13 | guerrero negro
# Processing Record 13 of Set 13 | concordia
# Processing Record 14 of Set 13 | suzuka
# Processing Record 15 of Set 13 | hope
# Processing Record 16 of Set 13 | oranzherei
# Processing Record 17 of Set 13 | arzgir
# Processing Record 18 of Set 13 | mayumba
# Processing Record 19 of Set 13 | awbari
# Processing Record 20 of Set 13 | bonthe
# Processing Record 21 of Set 13 | songjianghe
# Processing Record 22 of Set 13 | bafq
# Processing Record 23 of Set 13 | alcantara
# Processing Record 24 of Set 13 | tamandare
# Processing Record 25 of Set 13 | saint-pierre
# Processing Record 26 of Set 13 | valparaiso
# Processing Record 27 of Set 13 | port moresby
# Processing Record 28 of Set 13 | hay river
# Processing Record 29 of Set 13 | panguna
# Processing Record 30 of Set 13 | voh
# Processing Record 31 of Set 13 | strzelce opolskie
# Processing Record 32 of Set 13 | masumbwe
# Processing Record 33 of Set 13 | tutoia
# Processing Record 34 of Set 13 | atar
# Processing Record 35 of Set 13 | debre birhan
# Processing Record 36 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 13 | kiboga
# Processing Record 38 of Set 13 | wundanyi
# Processing Record 39 of Set 13 | cristesti
# Processing Record 40 of Set 13 | kununurra
# Processing Record 41 of Set 13 | vestmanna
# Processing Record 42 of Set 13 | havoysund
# Processing Record 43 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 13 | yinchuan
# Processing Record 45 of Set 13 | listvyanskiy
# Processing Record 46 of Set 13 | imbituba
# Processing Record 47 of Set 13 | ghanzi
# Processing Record 48 of Set 13 | leningradskiy
# Processing Record 49 of Set 13 | chegdomyn
# Processing Record 50 of Set 13 | ouesso
# Processing Record 1 of Set 14 | kosa
# Processing Record 2 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 14 | norrtalje
# Processing Record 4 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 14 | verkhoyansk
# Processing Record 6 of Set 14 | kamaishi
# Processing Record 7 of Set 14 | acajutla
# Processing Record 8 of Set 14 | san juan
# Processing Record 9 of Set 14 | touros
# Processing Record 10 of Set 14 | saint-leu
# Processing Record 11 of Set 14 | melville
# Processing Record 12 of Set 14 | singapore
# Processing Record 13 of Set 14 | oxelosund
# Processing Record 14 of Set 14 | ulaangom
# Processing Record 15 of Set 14 | port lincoln
# Processing Record 16 of Set 14 | pitelino
# Processing Record 17 of Set 14 | cajati
# Processing Record 18 of Set 14 | were ilu
# Processing Record 19 of Set 14 | menongue
# Processing Record 20 of Set 14 | wanning
# Processing Record 21 of Set 14 | izumo
# Processing Record 22 of Set 14 | te anau
# Processing Record 23 of Set 14 | constitucion
# Processing Record 24 of Set 14 | nakapiripirit
# Processing Record 25 of Set 14 | umba
# Processing Record 26 of Set 14 | zeya
# Processing Record 27 of Set 14 | krasnoselkup
# Processing Record 28 of Set 14 | beloha
# Processing Record 29 of Set 14 | itoman
# Processing Record 30 of Set 14 | ketchikan
# Processing Record 31 of Set 14 | omsukchan
# Processing Record 32 of Set 14 | kargapolye
# City not found. Skipping...
# Processing Record 33 of Set 14 | san lorenzo
# Processing Record 34 of Set 14 | hirado
# Processing Record 35 of Set 14 | shalakusha
# Processing Record 36 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 14 | yulara
# Processing Record 38 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 14 | esik
# Processing Record 40 of Set 14 | rusera
# Processing Record 41 of Set 14 | kikwit
# Processing Record 42 of Set 14 | aswan
# Processing Record 43 of Set 14 | abu samrah
# Processing Record 44 of Set 14 | rawson
# Processing Record 45 of Set 14 | taveta
# Processing Record 46 of Set 14 | moultrie
# Processing Record 47 of Set 14 | sept-iles
# Processing Record 48 of Set 14 | vitry-le-francois
# Processing Record 49 of Set 14 | ratholo
# Processing Record 50 of Set 14 | fergus falls
# Processing Record 1 of Set 15 | ljungby
# Processing Record 2 of Set 15 | excelsior springs
# Processing Record 3 of Set 15 | palmer
# Processing Record 4 of Set 15 | katangli
# Processing Record 5 of Set 15 | nishihara
# Processing Record 6 of Set 15 | aberdeen
# Processing Record 7 of Set 15 | sompeta
# Processing Record 8 of Set 15 | huarmey
# Processing Record 9 of Set 15 | jibuti
# Processing Record 10 of Set 15 | shirokiy
# Processing Record 11 of Set 15 | konya
# Processing Record 12 of Set 15 | campo de criptana
# Processing Record 13 of Set 15 | westport
# Processing Record 14 of Set 15 | williston
# Processing Record 15 of Set 15 | nabulao
# Processing Record 16 of Set 15 | darhan
# Processing Record 17 of Set 15 | daru
# Processing Record 18 of Set 15 | presidencia roque saenz pena
# Processing Record 19 of Set 15 | college
# Processing Record 20 of Set 15 | molepolole
# Processing Record 21 of Set 15 | ruston
# Processing Record 22 of Set 15 | anito
# Processing Record 23 of Set 15 | maniitsoq
# Processing Record 24 of Set 15 | taoudenni
# Processing Record 25 of Set 15 | sao geraldo do araguaia
# Processing Record 26 of Set 15 | grindavik
# Processing Record 27 of Set 15 | kostomuksha
# Processing Record 28 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 15 | takapau
# Processing Record 30 of Set 15 | bulungu
# Processing Record 31 of Set 15 | asfi
# Processing Record 32 of Set 15 | kitimat
# Processing Record 33 of Set 15 | sulangan
# Processing Record 34 of Set 15 | san carlos de bariloche
# Processing Record 35 of Set 15 | juneau
# Processing Record 36 of Set 15 | mazyr
# Processing Record 37 of Set 15 | stony point
# Processing Record 38 of Set 15 | cap malheureux
# Processing Record 39 of Set 15 | bolotnoye
# Processing Record 40 of Set 15 | kuytun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe      RE -21.3585   55.7679     76.59        81         100
# 1     Yellowknife      CA  62.4560 -114.3525     12.42        99          75
# 2  Roanoke Rapids      US  36.4615  -77.6542     53.24        62          75
# 3         Rikitea      PF -23.1203 -134.9692     77.92        77           5
# 4       Geraldton      AU -28.7667  114.6000     68.41        83         100
# 5    Punta Arenas      CL -53.1500  -70.9167     53.71        47          40
# 6      Butaritari      KI   3.0707  172.7902     81.63        81          64
# 7           Bluff      NZ -46.6000  168.3333     49.80        79          27
# 8           Sitka      US  57.0531 -135.3300     46.29        71         100
# 9      Vila Velha      BR -20.3297  -40.2925     82.35        71           0
#
#    Wind Speed Current Description
# 0        6.22     overcast clouds
# 1        5.75          light snow
# 2       17.27       broken clouds
# 3       21.92           clear sky
# 4       10.36     overcast clouds
# 5       17.27          light rain
# 6       16.91          light rain
# 7        5.97    scattered clouds
# 8       20.71          light rain
# 9        1.01           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
